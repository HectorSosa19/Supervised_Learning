# %%
import sklearn as sk
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

#Reading the house data
read_csv = pd.read_csv("../houses-data/datos.csv")
print(read_csv)
x = read_csv[['Tamaño','Num_Habitaciones' ,'Edad']]
y = read_csv['Precio']
#Divide all the data to training and testing
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size=0.2 , random_state=0)

#Create model to lineal regression
model = LinearRegression()

#Training Model
model.fit(x_train , y_train)

#Predict model
y_pred = model.predict(x_test)
#Calculate performance metrics
mse = mean_squared_error(y_test , y_pred)
r2 = r2_score(y_test , y_pred)

real_price = [300,400,500,600,700]
predict_model= [320,380,520,590,720]
total = real_price ^ r2
print(total)
print('Squared error of performance(MSE):' , mse)
print('Print performance metrics(R^2)' , r2)
# Out:
#     Tamaño  Num_Habitaciones   Ubicacion  Edad   Precio
# 0     1500                 3  Buenavista     5   300000
# 1     1200                 2    Laureles    10   250000
# 2     1700                 4     Poblado     2   400000
# 3      900                 2       Belén     7   230000
# 4     1100                 3    Envigado     6   280000
# 5     1300                 3  Buenavista     4   310000
# 6     1600                 4    Laureles     8   380000
# 7     1400                 3       Belén     9   320000
# 8     1800                 4    Envigado     5   420000
# 9     2000                 4     Poblado     3   450000
# 10    2100                 5  Buenavista     4   480000
# 11    2500                 5    Laureles     6   520000
# 12    2200                 4       Belén    10   470000
# 13    2800                 5    Envigado     7   580000
# 14    3000                 5     Poblado     4   610000
# 15    3100                 6  Buenavista     3   640000
# 16    3400                 6    Laureles     5   690000
# 17    3200                 5       Belén     8   670000
# 18    3500                 6    Envigado     4   720000
# 19    3700                 6     Poblado     2   750000
# 20    4100                 7  Buenavista     1   810000
# 21    4200                 7    Laureles     3   820000
# 22    4000                 6       Belén     6   800000
# 23    4300                 7    Envigado     5   850000
# 24    4500                 7     Poblado     4   880000
# 25    4800                 8  Buenavista     2   930000
# 26    4900                 8    Laureles     7   940000
# 27    3800                 6    Envigado     5   770000
# 28    3900                 6     Poblado     4   800000
# 29    4300                 7  Buenavista     3   880000
# 30    4500                 7    Laureles     2   920000
# 31    5000                 8       Belén     1   980000
# 32    5200                 8    Envigado     4  1000000
# 33    5500                 8     Poblado     5  1050000
# 34    5900                 9  Buenavista     3  1100000
# 35    6100                 9    Laureles     2  1120000
# 36    5500                 8       Belén     6  1060000
# 37    5900                 9    Envigado     7  1100000
# 38    6200                 9     Poblado     8  1150000
# 39    6600                10  Buenavista     5  1200000
# 40    6800                10    Laureles     4  1250000
# 41    7000                10       Belén     3  1300000
# 42    7200                10    Envigado     2  1350000
# 43    7500                10     Poblado     1  1400000
# Squared error of performance(MSE): 439981134.68217283
# Print performance metrics(R^2) 0.9942524155873212
